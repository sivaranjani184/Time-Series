# %%
#pip install nsepy
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36105 sha256=d79ab3d45913f9549e6a5ae02b9a95dccad8186083f0858ef0ab98e7003a012c
#   Stored in directory: c:\users\surya muruganantham\appdata\local\pip\cache\wheels\94\a7\d4\0e4e94292f5761407472684b2cd74771e9985af72f968101e0
# Successfully built nsepy
# ...
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'nsepy' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'nsepy'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
pip install nselib
# Out:
# ...
#
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ---------------------------------------- 0/6 [pypdf]
#    ------ --------------------------------- 1/6 [pyluach]
#    -------------------- ------------------- 3/6 [exchange-calendars]
#    -------------------- ------------------- 3/6 [exchange-calendars]
#    -------------------- ------------------- 3/6 [exchange-calendars]
#    -------------------- ------------------- 3/6 [exchange-calendars]
#    -------------------- ------------------- 3/6 [exchange-calendars]
# ...

# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
from nselib import capital_market as cm

# Define dates as strings in DD-MM-YYYY format
start_date = '01-06-2021'
end_date = '05-01-2022'

# Use the correct function: price_volume_data
stk_data = cm.price_volume_data(symbol='TATACOFFEE', from_date=start_date, to_date=end_date)

print(stk_data.head())
# Out:
#        Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0  TATACOFFEE     EQ  05-Jan-2022     217.80     218.50      218.7    214.30
# 1  TATACOFFEE     EQ  04-Jan-2022     214.05     214.90      220.8    212.45
# 2  TATACOFFEE     EQ  03-Jan-2022     213.15     213.95      216.9    212.30
# 3  TATACOFFEE     EQ  31-Dec-2021     208.50     208.90      216.2    208.40
# 4  TATACOFFEE     EQ  30-Dec-2021     211.35     211.45      211.5    207.90
#
#    LastPrice  ClosePrice  AveragePrice TotalTradedQuantity        Turnover₹  \
# 0     214.65      214.85        215.72           13,50,483  29,13,25,687.40
# 1     217.40      217.80        217.41           34,77,443  75,60,37,979.15
# 2     214.30      214.05        214.76           15,25,259  32,75,66,528.25
# 3     213.70      213.15        213.37           30,45,699  64,98,54,073.20
# 4     208.80      208.50        209.36            9,77,484  20,46,47,553.50
#
#   No.ofTrades
# 0      12,079
# 1      28,871
# ...

# %%
stk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Symbol               151 non-null    object
#  1   Series               151 non-null    object
#  2   Date                 151 non-null    object
#  3   PrevClose            151 non-null    float64
#  4   OpenPrice            151 non-null    float64
#  5   HighPrice            151 non-null    float64
#  6   LowPrice             151 non-null    float64
#  7   LastPrice            151 non-null    float64
#  8   ClosePrice           151 non-null    float64
#  9   AveragePrice         151 non-null    float64
#  10  TotalTradedQuantity  151 non-null    object
#  11  Turnover₹            151 non-null    object
#  12  No.ofTrades          151 non-null    object
# dtypes: float64(7), object(6)
# memory usage: 15.5+ KB

# %%
stk_data
# Out:
#          Symbol Series         Date  PrevClose  OpenPrice  HighPrice  \
# 0    TATACOFFEE     EQ  05-Jan-2022     217.80     218.50     218.70
# 1    TATACOFFEE     EQ  04-Jan-2022     214.05     214.90     220.80
# 2    TATACOFFEE     EQ  03-Jan-2022     213.15     213.95     216.90
# 3    TATACOFFEE     EQ  31-Dec-2021     208.50     208.90     216.20
# 4    TATACOFFEE     EQ  30-Dec-2021     211.35     211.45     211.50
# ..          ...    ...          ...        ...        ...        ...
# 146  TATACOFFEE     EQ  07-Jun-2021     174.35     176.40     176.65
# 147  TATACOFFEE     EQ  04-Jun-2021     176.70     177.90     177.90
# 148  TATACOFFEE     EQ  03-Jun-2021     174.00     176.90     178.70
# 149  TATACOFFEE     EQ  02-Jun-2021     174.25     173.55     175.65
# 150  TATACOFFEE     EQ  01-Jun-2021     179.20     180.00     181.35
#
#      LowPrice  LastPrice  ClosePrice  AveragePrice TotalTradedQuantity  \
# ...

# %%
LowPrice=stk_data["LowPrice"]

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['PrevClose', 'OpenPrice', 'HighPrice', 'LowPrice', 'LastPrice', 'ClosePrice', 'AveragePrice']
# The Qualtitative Data ['Symbol', 'Series', 'Date', 'TotalTradedQuantity', 'Turnover₹', 'No.ofTrades']

# %%
des_data=obj.descriptive_Analysis(dataset,quan)
# Out:
# D:\Doc\S Sivaranjani\AI\12.Time Series Analysis\Descriptive.py:24: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   des_data[i]["Null_count"]=dataset[i].isnull().sum()
# ...

# %%
des_data
# Out:
#                 PrevClose   OpenPrice   HighPrice    LowPrice   LastPrice  \
# Null_count              0           0           0           0           0
# NonNull_count         151         151         151         151         151
# Total_Count           151         151         151         151         151
# Mean           203.823841  204.717881  208.364901  200.768543  204.158609
# Median              206.1       207.1      210.35       203.8       206.5
# Mode               174.35       213.0       178.7       196.0       213.0
# Std             14.868758   15.154832   15.771568   14.592693    14.80016
# Min                 172.9      170.05      175.65       168.0       172.5
# Q1:25%             192.65     193.525       198.1       189.9     193.775
# Q2:50%              206.1       207.1      210.35       203.8       206.5
# Q3:75%             213.15     213.925     218.125      210.35       213.4
# Q4:100%             235.8       241.0       254.4      231.25      237.75
# ...

# %%
des_data["LowPrice"]
# Out:
# Null_count                0
# NonNull_count           151
# Total_Count             151
# Mean             200.768543
# Median                203.8
# Mode                  196.0
# Std               14.592693
# Min                   168.0
# Q1:25%                189.9
# Q2:50%                203.8
# Q3:75%               210.35
# Q4:100%              231.25
# IQR                   20.45
# 1.5Rule              30.675
# Lesser              159.225
# Greater             241.025
# Name: LowPrice, dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset["LowPrice"],99)
# Out:
# 229.925

# %%
np.percentile(dataset["HighPrice"],80)
# Out:
# 219.25

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["LowPrice"],219,230)
# Out:
# C:\Users\SURYA MURUGANANTHAM\AppData\Local\Temp\ipykernel_18772\2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=200.769, Standard Deviation=14.593
# The area between range(219,230):0.08765971141467199
# 0.08765971141467199

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["LowPrice"])
# Out:
# C:\Users\SURYA MURUGANANTHAM\AppData\Local\Temp\ipykernel_18772\3468099301.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable("LowPrice",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           196.00          3      1.986755    1.986755
# 1           187.50          2      1.324503    3.311258
# 2           201.50          2      1.324503    4.635762
# 3           207.15          2      1.324503    5.960265
# 4           189.50          2      1.324503    7.284768
# ..             ...        ...           ...         ...
# 133         208.55          1      0.662252   97.350993
# 134         203.80          1      0.662252   98.013245
# 135         211.10          1      0.662252   98.675497
# 136         211.50          1      0.662252   99.337748
# 137         172.65          1      0.662252  100.000000
#
# [138 rows x 4 columns]

# %%
freqTable("HighPrice",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           218.70          2      1.324503    1.324503
# 1           193.95          2      1.324503    2.649007
# 2           189.00          2      1.324503    3.973510
# 3           178.70          2      1.324503    5.298013
# 4           214.70          2      1.324503    6.622517
# ..             ...        ...           ...         ...
# 135         212.00          1      0.662252   97.350993
# 136         215.85          1      0.662252   98.013245
# 137         215.35          1      0.662252   98.675497
# 138         214.15          1      0.662252   99.337748
# 139         181.35          1      0.662252  100.000000
#
# [140 rows x 4 columns]

# %%
fh=freqTable("HighPrice",dataset)

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           218.70          2      1.324503    1.324503
# 6           206.00          2      1.324503    9.271523
# 1           193.95          2      1.324503    2.649007
# 10          218.30          2      1.324503   14.569536
# 8           204.05          2      1.324503   11.920530
# ..             ...        ...           ...         ...
# 47          184.70          1      0.662252   39.072848
# 46          178.90          1      0.662252   38.410596
# 45          176.65          1      0.662252   37.748344
# 44          177.90          1      0.662252   37.086093
# 139         181.35          1      0.662252  100.000000
#
# [140 rows x 4 columns]

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 0     218.70
# 10    218.30
# 4     214.70
# 5     213.00
# 9     209.50
# 7     207.80
# 6     206.00
# 8     204.05
# 1     193.95
# 2     189.00
# 3     178.70
# Name: Unique_Values, dtype: float64
